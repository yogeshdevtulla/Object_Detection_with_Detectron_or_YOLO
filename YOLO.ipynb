# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Sat Jul 22 08:25:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd /content/drive/MyDrive/yolo/datasets/data
# Out:
# /content/drive/MyDrive/yolo/datasets/data

# %%
# !ls
# Out:
# data.yaml  runs  test  train  valid  yolov8n.pt  yolov8s.pt

# %%
# install yolo
# !pip install ultralytics

# %%
from ultralytics import YOLO

from IPython.display import display ,Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=224 plots=True

# %%
# !ls runs/detect/train/

# %%
Image(filename='/content/drive/MyDrive/yolo/datasets/data/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/yolo/datasets/data/runs/detect/train/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/yolo/datasets/data/runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/yolo/datasets/data/runs/detect/train/weights/best.pt data=data.yaml

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolo/datasets/data/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/yolo/datasets/data/test/images
# Out:
# Ultralytics YOLOv8.0.139 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients
#
# image 1/31 /content/drive/MyDrive/yolo/datasets/data/test/images/1.jpeg: 192x224 2 Goggless, 2 Glovess, 377.0ms
# image 2/31 /content/drive/MyDrive/yolo/datasets/data/test/images/10.jpeg: 160x224 3 Glovess, 300.0ms
# image 3/31 /content/drive/MyDrive/yolo/datasets/data/test/images/11.jpeg: 224x224 4 Glovess, 36.5ms
# image 4/31 /content/drive/MyDrive/yolo/datasets/data/test/images/12.jpeg: 192x224 2 Glovess, 34.3ms
# image 5/31 /content/drive/MyDrive/yolo/datasets/data/test/images/13.jpeg: 128x224 1 Gloves, 270.8ms
# image 6/31 /content/drive/MyDrive/yolo/datasets/data/test/images/14(1).jpeg: 224x224 2 Glovess, 18.5ms
# image 7/31 /content/drive/MyDrive/yolo/datasets/data/test/images/14.jpg: 192x224 2 Helmets, 2 Goggless, 3 Glovess, 18.6ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/yolo/datasets/data/runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
